# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
from scipy import stats
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
file_to_load = "/Users/fernandaw/Documents/CODE/COVID-PREJUDICE/prejudice_filtered.csv"

# Read Purchasing File and store into Pandas data frame
df = pd.read_csv(file_to_load, encoding= 'unicode_escape')

# %%
#df.head()

# %%
# loc a specific row and use this to validate your steps after you create the list
df.loc[(df["Random ID"] == 144706383)]
# Out:
#     Random ID      StartDate        EndDate  Status      IPAddress  Progress  \
# 38  144706383  11/2/20 16:11  11/2/20 16:23       0  73.208.88.102       100
#
#     Duration (in seconds)  Finished   RecordedDate         ResponseId  ...  \
# 38                    739         1  11/2/20 16:23  R_2sYeCZ023WgKTz3  ...
#
#     Education_8_TEXT  YrsEmploy             Q99  CurrentlyEmploy  Industry  \
# 38               NaN        6.0  BACK TO FUTURE                1      12.0
#
#     Q_BallotBoxStuffing Q_RecaptchaScore Q_RelevantIDDuplicate  \
# 38                  NaN              NaN                   NaN
#
#     Q_RelevantIDDuplicateScore  Q_RelevantIDFraudScore
# 38                         NaN                     NaN
#
# [1 rows x 194 columns]

# %%
# use this space to drop a list of the random ID's that are rejected
rejected = [120997555, 135794307, 144152673, 144706383, 145114616, 153351508,
           154161129, 175159924, 192718649, 194244403, 202069853, 206122255,
           206122255,216650040,218872737,220407042,240305183, 242998517,243585190,
           251578216,255945501,264455176,265368713,267160831, 284702893,291605500,
           300671783,302348996,306729891,325277599,328650251,330369589,330978939,
           340985803,351913020,355112243,369634962,376531060,387305141,412999839,
           415658442,416167028,418714545,427605172,447828564,448265245,453530551,
           458391034,471146368,472008118,474121206,474965262,479747057,480839354,
           482203736,503744193,505142836,515479506,518434566,528104151,528832892,
           529175953,538764304,538914042,539329199,546343878,546760211,554782452,
           559659099,567586724,574704603,589318510,591276416,591555325,595109448,
           596934110,599245636,603495195,604858691,607179717,611025292,612322414,
           614937712,623930746,626098700,628812425,641950000,664550781,671331238,
           678798973,680002231,682563598,684078816,686330386,698715470,711033053,
           735834459,737369469,737536673,738935493,750576188,758386166,764832936,
           774725771,777828372,778276487,778298192,800127502,800913256,803917612,
           806359675,810573767,833389026,849377626,858897399,861489706,864916688,
           869379163,870013246,874479466,877388302,879376868,883492194,892779994,
           894467416,894734119,895254668,899403984,905182401,909923801,916335178,
           918311230,925457168,936484651,940976208,951779986,959794470,964876108,
           965037590,970467880,971914280,973778980,986042046,987158905,995896708]

# %%
# create a dataframe with rejected IDs, then one with accepted IDs
rejected_IDS = df[df['Random ID'].isin(rejected)] #the only difference here is the ~ symbol
accepted_IDS = df[~df['Random ID'].isin(rejected)]

# %%
#rejected_IDS

# %%
#accepted_IDS

# %%
# repeat this code to see if the manipulation worked, for accepted IDs
accepted_IDS.loc[(df["Random ID"] == 144706383)]
# Out:
# Empty DataFrame
# ...

# %%
# repeat this code to see if the manipulation worked, for rejected IDs
rejected_IDS.loc[(df["Random ID"] == 144706383)]
# Out:
#     Random ID      StartDate        EndDate  Status      IPAddress  Progress  \
# 38  144706383  11/2/20 16:11  11/2/20 16:23       0  73.208.88.102       100
#
#     Duration (in seconds)  Finished   RecordedDate         ResponseId  ...  \
# 38                    739         1  11/2/20 16:23  R_2sYeCZ023WgKTz3  ...
#
#     Education_8_TEXT  YrsEmploy             Q99  CurrentlyEmploy  Industry  \
# 38               NaN        6.0  BACK TO FUTURE                1      12.0
#
#     Q_BallotBoxStuffing Q_RecaptchaScore Q_RelevantIDDuplicate  \
# 38                  NaN              NaN                   NaN
#
#     Q_RelevantIDDuplicateScore  Q_RelevantIDFraudScore
# 38                         NaN                     NaN
#
# [1 rows x 194 columns]

# %%
# yay! Save accepted IDs to a new csv file for R analysis
accepted_IDS.to_csv(r'/Users/fernandaw/Documents/CODE/COVID-PREJUDICE/prejudice_filtered_2.0.csv')

# %%
IP_frequency = df["IPAddress"].value_counts()

for x in IP_frequency:
    if x != 1:
        print(x)
    else:
        print("safe participant")
# Out:
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# safe participant
# ...
